# %%
import pandas as pd
import matplotlib.pyplot as plt

print("Python + packages are working ✅")
# Out:
# Python + packages are working ✅

# %%
df = pd.DataFrame({"a":[1,2,3], "b":[10,20,30]})
df
# Out:
#    a   b
# 0  1  10
# 1  2  20
# 2  3  30

# %%
df.plot(kind="line")
plt.show()

# %%
1+1
# Out:
# 2
