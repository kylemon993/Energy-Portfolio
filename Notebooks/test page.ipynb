# %%
import os
from pathlib import Path

os.getcwd(), Path.cwd()
# Out:
# ('c:\\DataAnalystTraining\\Energy-Portfolio\\Notebooks',
#  WindowsPath('c:/DataAnalystTraining/Energy-Portfolio/Notebooks'))

# %%
from pathlib import Path

Path("outputs/figures").exists(), list(Path("outputs/figures").glob("*"))
# Out:
# (True,
#  [WindowsPath('outputs/figures/day3_frequency_rolling.png'),
#   WindowsPath('outputs/figures/day3_frequency_timeseries.png')])

# %%
from pathlib import Path
import os


PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "README.md").exists():
    
    for parent in Path.cwd().parents:
        if (parent / "README.md").exists():
            PROJECT_ROOT = parent
            break

save_dir = PROJECT_ROOT / "outputs" / "figures"
save_dir.mkdir(parents=True, exist_ok=True)

save_path = save_dir / "day3_frequency_rolling.png"
plt.gcf().savefig(save_path, dpi=150, bbox_inches="tight")

str(save_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 17
#      14 save_dir.mkdir(parents=True, exist_ok=True)
#      16 save_path = save_dir / "day3_frequency_rolling.png"
# ---> 17 plt.gcf().savefig(save_path, dpi=150, bbox_inches="tight")
#      19 str(save_path)
#
# NameError: name 'plt' is not defined
